# %% [markdown]
# # Task 0
# Import the two libraries numpy and matplotlib by running the cell below. Notice how the two libraries were imported using an alias (as ...). Read more about importing python libraries/modules here:
#
# www.geeksforgeeks.org/import-module-python/.
#
# Print your name using the `student_name` variable: it should be a string (www.geeksforgeeks.org/python/python-string/).

# %%
import numpy as np
import matplotlib.pyplot as plt

student_name = 'Name Surname'
print(student_name)
# Out:
# Name Surname

# %% [markdown]
# # Task 1
#
# The informatic variable `error` contains measurement error values generated sinthetically using the normal distribution implemented within the Numpy `np.random.normal` python function (https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) with the following parameters:
#
# *   `expected_mean = 0`;
# *   `expected_sigma = 0.3`;
# *   `number of samples = 50`.
#
# Calculate the sample mean and sample standard deviation of the data stored in the `error` variable using `numpy` library functions.
#
# Below the links to the official Numpy online documentation and an additional references:
#
#
# *   https://numpy.org/doc/stable/;
# *  https://numpy.org/devdocs/reference/generated/numpy.std.html (be careful with the numpy implementation of the standard deviaition)
# *   www.geeksforgeeks.org/python/compute-the-mean-standard-deviation-and-variance-of-a-given-numpy-array/.
#
# Inspect the histogram of the error values and the values obtained for the sample mean and the sample standard deviation.
#
# Then answer the questions.

# %%
# The following two lines will generate a random dataset
# of random errors with number_of_samples samples and a sigma of 0.3 m
# https://numpy.org/doc/2.3/reference/random/generated/numpy.random.normal.html

expected_mean = 0
expected_std = 0.3
number_of_samples = 50 # replace it with 10, 1000 and 10000 to answer Q3. To answer Q4, set it again to 50.
error = np.random.normal(expected_mean, expected_std, number_of_samples)

# Printing the (number_of_samples) values inside my error variable
print(number_of_samples,'error values (realizations) (m)\n', error)

# Task 1.
# Compute the sample mean and sample standard deviation (std)
# of the dataset stored in the variable error
# Use the numpy functions
# Complete the following two lines

error_sample_mean = 0 # replace zero with the correct answer
error_sample_std  = 0 # replace zero with the correct answer

print('error_sample_mean (m)\n',error_sample_mean)
print('error_sample_std (m)\n', error_sample_std)

# Plotting the histogram of the dataset error
count, bins, ignored = plt.hist(error, bins = 15, density=False) # Q4: what happens if density is True?
plt.show()


area_under_the_hisotgram = np.sum(count * np.diff(bins))
print('Area under the histogram:',area_under_the_hisotgram)
# Out:
# 50 error values (realizations) (m)
#  [-3.32993446e-01 -1.65763835e-01  1.22574426e-01 -7.31217856e-02
#  -7.47512187e-02  1.99685264e-01 -7.81873654e-02  2.73430721e-01
#   9.32792191e-02 -8.61063694e-02  3.15467578e-01  6.77820409e-01
#  -9.23602472e-02 -4.81361189e-01 -5.21184175e-01 -4.13010027e-04
#  -3.03241518e-01  2.75282313e-02  3.76765979e-01 -3.48557747e-03
#  -3.02027257e-01  2.50047101e-02  2.91513933e-02 -1.36821999e-01
#  -8.17068659e-02  8.77721084e-02 -1.89725078e-01  7.43515362e-02
#  -3.76280190e-01  6.09815293e-02 -8.97698841e-02 -1.13669590e-01
#   1.12465049e-01 -3.63576403e-01 -1.71868751e-01 -4.01537861e-01
#  -4.68651912e-02  4.41694150e-01 -5.09141841e-01 -1.23310275e-01
#   1.60209834e-01 -3.61091263e-01  5.40120995e-01  2.53316134e-01
#   4.01323994e-01 -2.30850709e-01 -3.52721924e-01 -2.03976803e-02
#   6.33066941e-02  1.88099062e-01]
# error_sample_mean (m)
#  0
# error_sample_std (m)
#  0
# Area under the histogram: 3.9966819492611174

# %% [markdown]
# **Q1:** Run the cell several times, keeping the number of samples fixed. Look at the sample mean and sample standard deviation obtained each time. Do these values vary from one run to another? Why? Briefly justify your answer.
#
# ***EDIT CELL TO ANSWER***
#
# **Q2:** Compare the histogram of the simulated errors with the theoretical Gaussian distribution used to generate them. Does the histogram appear consistent with a Gaussian distribution? Briefly justify your answer
#
# ***EDIT CELL TO ANSWER***
#
# **Q3:** Repeat the experiment using different numbers of samples: 10, 1000, 10000? Compare the resulting sample mean and sample standard deviation, as well as the corresponding histograms. How does increasing/decreasing the number of samples affect the stability of the estimated mean and standard deviation and the shape of the histogram?
#
#
# ***EDIT CELL TO ANSWER***
#
# **Q4:** Repeat the plot with density=True instead of density=False. How does the histogram change? What does the area under the histogram represent in this case? Briefly explain the relationship between this histogram and a probability density function.
#
# ***EDIT CELL TO ANSWER***

# %% [markdown]
# # Task 2
#
# The following cell add an outlier to the value of the tenth error (index=9), creating a new dataset stored in the variable`error_outlier`.
#
# Then it shortens the new dataset considering just the first ten error values, creating a new additional dataset stored in the variable `error_outlier_10`.
#
# Notice how it is possible in python to create a subset of the array/list using the slice operation (`error[i:j]`) where i,j represent the start (inclusive) and end (not included) index of the part of the array to extract.
#
# For more information on the slice operation refer to:
#
# www.geeksforgeeks.org/python-slice-function/.
#
# Rerun the previous cell with 50 samples.
#
# Then calculate and print the mean, median and standard deviation for the two resulting datsets stored in the `error_outlier` and `error_outlier_10`  variables and compare the results.

# %%
# Now we add a blunder (outlier) in the dataset
# creating a new dataset (error_outlier_outlier)
error_outlier = error.copy()
outlier = 10
error_outlier[9] = error_outlier[9] + outlier

# TASK 2.
# Compute the sample std, sample median and sample mean of the new dataset, which contains an outlier
# Complete the following lines:

error_outlier_sample_mean   = 0   # replace zero with the correct answer
error_outlier_sample_median = 0   # replace zero with the correct answer
error_outlier_sample_std    = 0   # replace zero with the correct answer

print('error_outlier_sample_mean (m)\n',error_outlier_sample_mean)
print('error_outlier_sample_median (m)\n',error_outlier_sample_median)
print('error_outlier_sample_std (m)\n',error_outlier_sample_std)

# Now we shorten the new dataset to the first 10 entries,
# creating an additional dataset (error_outlier_10)
# This will affect the influence of the outlier on the mean and std.

error_outlier_10 = error_outlier[0:10]

# TASK 2. Compute the sample std, sample mean and sample median
# of the shorter dataset with the blunder.
# Complete the following lines:

error_outlier_10_sample_mean   = 0    # replace zero with the correct answer
error_outlier_10_sample_median = 0    # replace zero with the correct answer
error_outlier_10_sample_std    = 0    # replace zero with the correct answer

print('error_outlier_10_sample_mean (m)\n',error_outlier_10_sample_mean)
print('error_outlier_10_sample_median (m)\n',error_outlier_10_sample_median)
print('error_outlier_10_sample_std (m)\n',error_outlier_10_sample_std)
# Out:
# error_outlier_sample_mean (m)
#  0
# error_outlier_sample_median (m)
#  0
# error_outlier_sample_std (m)
#  0
# error_outlier_10_sample_mean (m)
#  0
# error_outlier_10_sample_median (m)
#  0
# error_outlier_10_sample_std (m)
#  0

# %% [markdown]
# **Q5**:  What is the effect of the outlier on the sample mean, sample median and sample standard deviation? Compare these values for the two datasets, `error_outlier` and `error_outlier_10`.
#
# ***EDIT CELL TO ANSWER***
#
# **Q6**: Which of the three statistical parameters (sample mean, sample median or sample standard deviation) is the most robust to the presence of an outlier? Briefly justify your answer
#
# ***EDIT CELL TO ANSWER***

# %% [markdown]
# # Task 3
#
# Use the following code cell to plot the ordinary density histograms of the two datasets stored in the `error_outlier` and `error_outlier_10` variables.
#
# Select a suitable number of bins in order to improve the visualization of the two datasets and highlight the presence of the outlier.
#
# For more information on how to plot an histogram, refer to:
#
# *   www.geeksforgeeks.org/python/matplotlib-pyplot-hist-in-python/;
# *   https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html;
# *   https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html.
#
# Be careful to the `density` and `cumulative` parameters of the `matplotlib.pyplot.hist` function.

# %%
# Write the code to plot the histograms here

# %% [markdown]
# **Q7**: Compare the histograms obtained for `error_outlier` and `error_outlier_10`. Describe how the outlier affects the distribution of the observed errors, paying particular attention to the range of the values and to their spread around the mean. Considering the Gaussian distribution used to generate the errors, how likely would you expect such an extreme observation to be?
#
# ***EDIT CELL TO ANSWER***
